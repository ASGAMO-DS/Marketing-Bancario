# %% [markdown]
# # Explore here

# %%
# Importemos el CSV
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/logistic-regression-project-tutorial/main/bank-marketing-campaign-data.csv',sep=';')
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...         1    999         0
# 1      telephone   may         mon  ...         1    999         0
# 2      telephone   may         mon  ...         1    999         0
# 3      telephone   may         mon  ...         1    999         0
# 4      telephone   may         mon  ...         1    999         0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41183   cellular   nov         fri  ...         1    999         0
# 41184   cellular   nov         fri  ...         1    999         0
# 41185   cellular   nov         fri  ...         2    999         0
# 41186   cellular   nov         fri  ...         1    999         0
# 41187   cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %%
#Pongamos el Df dentro del proyecto

df.to_csv('../data/raw/originaldataframe.csv', index = False)

#Veamos la información del DF 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
#Veamos si hay valores duplicados

import utils as ut

ut.valores_duplicados(df)
# Out:
# en la columna age hay 41098 valores duplicados
# en la columna job hay 41164 valores duplicados
# en la columna marital hay 41172 valores duplicados
# en la columna education hay 41168 valores duplicados
# en la columna default hay 41173 valores duplicados
# en la columna housing hay 41173 valores duplicados
# en la columna loan hay 41173 valores duplicados
# en la columna contact hay 41174 valores duplicados
# en la columna month hay 41166 valores duplicados
# en la columna day_of_week hay 41171 valores duplicados
# en la columna duration hay 39632 valores duplicados
# en la columna campaign hay 41134 valores duplicados
# en la columna pdays hay 41149 valores duplicados
# en la columna previous hay 41168 valores duplicados
# en la columna poutcome hay 41173 valores duplicados
# en la columna emp.var.rate hay 41166 valores duplicados
# en la columna cons.price.idx hay 41150 valores duplicados
# en la columna cons.conf.idx hay 41150 valores duplicados
# en la columna euribor3m hay 40860 valores duplicados
# en la columna nr.employed hay 41165 valores duplicados
# en la columna y hay 41174 valores duplicados

# %%
#Eliminemos filas duplicadas, no se eliminan columnas porque no hay ID a eliminar por ejemplo

df = df.drop_duplicates().reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41176 entries, 0 to 41175
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             41176 non-null  object
#  2   marital         41176 non-null  object
#  3   education       41176 non-null  object
#  4   default         41176 non-null  object
#  5   housing         41176 non-null  object
#  6   loan            41176 non-null  object
#  7   contact         41176 non-null  object
#  8   month           41176 non-null  object
#  9   day_of_week     41176 non-null  object
#  10  duration        41176 non-null  int64
#  11  campaign        41176 non-null  int64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  object
#  15  emp.var.rate    41176 non-null  float64
#  16  cons.price.idx  41176 non-null  float64
#  17  cons.conf.idx   41176 non-null  float64
#  18  euribor3m       41176 non-null  float64
#  19  nr.employed     41176 non-null  float64
#  20  y               41176 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
#Eliminar columnas irrelevantes
#A priori eliminaría días de la semana y mes, pero no lo haré aún para evaluar en el EDA alguna posible estacionalidad.
#No veo columnas a eliminar con claridad, definiré las columnas a usar para plantear el modelo con el análisis estadístico más adelante.

# %%
#Análisis Univariante directamente ya que no hay valores nulos.

#Análisis de variables categóricas.

import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(4, 3, figsize = (10, 15))

Gráfico_Job = sns.histplot(ax=axis[0,0],data=df, x='job')
Gráfico_Job.set_ylabel('')
Gráfico_Job.set_xticklabels(axis[0,0].get_xticklabels(), rotation=90)
for p in Gráfico_Job.patches:
    Gráfico_Job.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_marital= sns.histplot(ax=axis[0,1],data=df, x='marital')
Gráfico_marital.set_ylabel('')
Gráfico_marital.set_xticklabels(axis[0,1].get_xticklabels(), rotation=90)
for p in Gráfico_marital.patches:
    Gráfico_marital.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )


Gráfico_education= sns.histplot(ax=axis[0,2],data=df, x='education')
Gráfico_education.set_ylabel('')
Gráfico_education.set_xticklabels(axis[0,2].get_xticklabels(), rotation=90)
for p in Gráfico_education.patches:
    Gráfico_education.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )


Gráfico_default=sns.histplot(ax=axis[1,0],data=df, x='default')
Gráfico_default.set_ylabel('')
for p in Gráfico_default.patches:
    Gráfico_default.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )


Gráfico_housing=sns.histplot(ax=axis[1,1],data=df, x='housing')
Gráfico_housing.set_ylabel('')
for p in Gráfico_housing.patches:
    Gráfico_housing.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_loan=sns.histplot(ax=axis[1,2],data=df, x='loan')
Gráfico_loan.set_ylabel('')
for p in Gráfico_loan.patches:
    Gráfico_loan.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_contact=sns.histplot(ax=axis[2,0],data=df, x='contact')
Gráfico_contact.set_ylabel('')
for p in Gráfico_contact.patches:
    Gráfico_contact.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_month=sns.histplot(ax=axis[2,1],data=df, x='month')
Gráfico_month.set_ylabel('')
Gráfico_month.set_xticklabels(axis[2,1].get_xticklabels(), rotation=90)
for p in Gráfico_month.patches:
    Gráfico_month.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_day_of_week=sns.histplot(ax=axis[2,2],data=df, x='day_of_week')
Gráfico_day_of_week.set_ylabel('')
for p in Gráfico_day_of_week.patches:
    Gráfico_day_of_week.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_poutcome=sns.histplot(ax=axis[3,0],data=df, x='poutcome')
Gráfico_poutcome.set_ylabel('')
for p in Gráfico_poutcome.patches:
    Gráfico_poutcome.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_y=sns.histplot(ax=axis[3,1],data=df, x='y')
Gráfico_y.set_ylabel('')
for p in Gráfico_y.patches:
    Gráfico_y.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_548/2053187976.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Gráfico_Job.set_xticklabels(axis[0,0].get_xticklabels(), rotation=90)
# /tmp/ipykernel_548/2053187976.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Gráfico_marital.set_xticklabels(axis[0,1].get_xticklabels(), rotation=90)
# /tmp/ipykernel_548/2053187976.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Gráfico_education.set_xticklabels(axis[0,2].get_xticklabels(), rotation=90)
# /tmp/ipykernel_548/2053187976.py:126: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Gráfico_month.set_xticklabels(axis[2,1].get_xticklabels(), rotation=90)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(4, 3, figsize = (10, 13))

sns.histplot(ax=axis[0,0],data=df, x='job').set_xticklabels(axis[0,0].get_xticklabels(), rotation=90)
sns.histplot(ax=axis[0,1],data=df, x='marital').set_xticklabels(axis[0,1].get_xticklabels(), rotation=90)
sns.histplot(ax=axis[0,2],data=df, x='education').set_xticklabels(axis[0,2].get_xticklabels(), rotation=90)
sns.histplot(ax=axis[1,0],data=df, x='default').set(ylabel=None)
sns.histplot(ax=axis[1,1],data=df, x='housing').set(ylabel=None)
sns.histplot(ax=axis[1,2],data=df, x='loan').set(ylabel=None)
sns.histplot(ax=axis[2,0],data=df, x='contact').set(ylabel=None)
sns.histplot(ax=axis[2,1],data=df, x='month').set_xticklabels(axis[2,1].get_xticklabels(), rotation=90)
sns.histplot(ax=axis[2,2],data=df, x='day_of_week').set(ylabel=None)
sns.histplot(ax=axis[3,0],data=df, x='poutcome').set(ylabel=None)
sns.histplot(ax=axis[3,1],data=df, x='y').set(ylabel=None)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_548/1314482536.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sns.histplot(ax=axis[0,0],data=df, x='job').set_xticklabels(axis[0,0].get_xticklabels(), rotation=90)
# /tmp/ipykernel_548/1314482536.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sns.histplot(ax=axis[0,1],data=df, x='marital').set_xticklabels(axis[0,1].get_xticklabels(), rotation=90)
# /tmp/ipykernel_548/1314482536.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sns.histplot(ax=axis[0,2],data=df, x='education').set_xticklabels(axis[0,2].get_xticklabels(), rotation=90)
# /tmp/ipykernel_548/1314482536.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sns.histplot(ax=axis[2,1],data=df, x='month').set_xticklabels(axis[2,1].get_xticklabels(), rotation=90)

# %%
#Varibles numéricas

fig, axis = plt.subplots(4, 2, figsize = (10, 7), gridspec_kw={'height_ratios': [6, 1,6,1]})

sns.histplot(ax=axis[0,0],data=df,x='price')
sns.boxplot(ax=axis[1,0],data=df,x='price')

sns.histplot(ax=axis[0,1],data=df,x='minimum_nights').set_xlim(0,150)
sns.boxplot(ax=axis[1,1],data=df,x='minimum_nights')

sns.histplot(ax=axis[2,0],data=df,x='calculated_host_listings_count').set_xlim(0,80)
sns.boxplot(ax=axis[3,0],data=df,x='calculated_host_listings_count')
plt.tight_layout()
plt.show()
