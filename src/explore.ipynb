# %% [markdown]
# # Explore here

# %%
# Importemos el CSV
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/logistic-regression-project-tutorial/main/bank-marketing-campaign-data.csv',sep=';')
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
#Pongamos el Df dentro del proyecto

df.to_csv('../data/raw/originaldataframe.csv', index = False)

#Veamos la información del DF 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
#Veamos si hay valores duplicados

import utils as ut

ut.valores_duplicados(df)
# Out:
# en la columna age hay 41110 valores duplicados
# en la columna job hay 41176 valores duplicados
# en la columna marital hay 41184 valores duplicados
# en la columna education hay 41180 valores duplicados
# en la columna default hay 41185 valores duplicados
# en la columna housing hay 41185 valores duplicados
# en la columna loan hay 41185 valores duplicados
# en la columna contact hay 41186 valores duplicados
# en la columna month hay 41178 valores duplicados
# en la columna day_of_week hay 41183 valores duplicados
# en la columna duration hay 39644 valores duplicados
# en la columna campaign hay 41146 valores duplicados
# en la columna pdays hay 41161 valores duplicados
# en la columna previous hay 41180 valores duplicados
# en la columna poutcome hay 41185 valores duplicados
# en la columna emp.var.rate hay 41178 valores duplicados
# en la columna cons.price.idx hay 41162 valores duplicados
# en la columna cons.conf.idx hay 41162 valores duplicados
# ...

# %%
#Eliminemos filas duplicadas, no se eliminan columnas porque no hay ID a eliminar por ejemplo

df = df.drop_duplicates().reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41176 entries, 0 to 41175
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             41176 non-null  object
#  2   marital         41176 non-null  object
#  3   education       41176 non-null  object
#  4   default         41176 non-null  object
#  5   housing         41176 non-null  object
#  6   loan            41176 non-null  object
#  7   contact         41176 non-null  object
#  8   month           41176 non-null  object
#  9   day_of_week     41176 non-null  object
#  10  duration        41176 non-null  int64
#  11  campaign        41176 non-null  int64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  object
#  15  emp.var.rate    41176 non-null  float64
#  16  cons.price.idx  41176 non-null  float64
# ...

# %%
#Eliminar columnas irrelevantes
#A priori eliminaría días de la semana y mes, pero no lo haré aún para evaluar en el EDA alguna posible estacionalidad.
#No veo columnas a eliminar con claridad, definiré las columnas a usar para plantear el modelo con el análisis estadístico más adelante.

# %%
#Análisis Univariante directamente ya que no hay valores nulos.

#Análisis de variables categóricas.

import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(4, 3, figsize = (10, 15))

Gráfico_Job = sns.histplot(ax=axis[0,0],data=df, x='job')
Gráfico_Job.set_ylabel('')
Gráfico_Job.set_xticklabels(axis[0,0].get_xticklabels(), rotation=90)
for p in Gráfico_Job.patches:
    Gráfico_Job.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_marital= sns.histplot(ax=axis[0,1],data=df, x='marital')
Gráfico_marital.set_ylabel('')
Gráfico_marital.set_xticklabels(axis[0,1].get_xticklabels(), rotation=90)
for p in Gráfico_marital.patches:
    Gráfico_marital.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )


Gráfico_education= sns.histplot(ax=axis[0,2],data=df, x='education')
Gráfico_education.set_ylabel('')
Gráfico_education.set_xticklabels(axis[0,2].get_xticklabels(), rotation=90)
for p in Gráfico_education.patches:
    Gráfico_education.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )


Gráfico_default=sns.histplot(ax=axis[1,0],data=df, x='default')
Gráfico_default.set_ylabel('')
for p in Gráfico_default.patches:
    Gráfico_default.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )


Gráfico_housing=sns.histplot(ax=axis[1,1],data=df, x='housing')
Gráfico_housing.set_ylabel('')
for p in Gráfico_housing.patches:
    Gráfico_housing.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_loan=sns.histplot(ax=axis[1,2],data=df, x='loan')
Gráfico_loan.set_ylabel('')
for p in Gráfico_loan.patches:
    Gráfico_loan.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_contact=sns.histplot(ax=axis[2,0],data=df, x='contact')
Gráfico_contact.set_ylabel('')
for p in Gráfico_contact.patches:
    Gráfico_contact.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_month=sns.histplot(ax=axis[2,1],data=df, x='month')
Gráfico_month.set_ylabel('')
Gráfico_month.set_xticklabels(axis[2,1].get_xticklabels(), rotation=90)
for p in Gráfico_month.patches:
    Gráfico_month.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_day_of_week=sns.histplot(ax=axis[2,2],data=df, x='day_of_week')
Gráfico_day_of_week.set_ylabel('')
for p in Gráfico_day_of_week.patches:
    Gráfico_day_of_week.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_poutcome=sns.histplot(ax=axis[3,0],data=df, x='poutcome')
Gráfico_poutcome.set_ylabel('')
for p in Gráfico_poutcome.patches:
    Gráfico_poutcome.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_y=sns.histplot(ax=axis[3,1],data=df, x='y')
Gráfico_y.set_ylabel('')
for p in Gráfico_y.patches:
    Gráfico_y.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_598/179898050.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Gráfico_Job.set_xticklabels(axis[0,0].get_xticklabels(), rotation=90)
# /tmp/ipykernel_598/179898050.py:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Gráfico_marital.set_xticklabels(axis[0,1].get_xticklabels(), rotation=90)
# /tmp/ipykernel_598/179898050.py:47: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Gráfico_education.set_xticklabels(axis[0,2].get_xticklabels(), rotation=90)
# /tmp/ipykernel_598/179898050.py:130: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Gráfico_month.set_xticklabels(axis[2,1].get_xticklabels(), rotation=90)

# %%
#Varibles numéricas

fig, axis = plt.subplots(10, 2, figsize = (15, 20), gridspec_kw={'height_ratios': [6, 1,6,1,6, 1,6,1,6,1]})

sns.histplot(ax=axis[0,0],data=df,x='age')
sns.boxplot(ax=axis[1,0],data=df,x='age')

sns.histplot(ax=axis[0,1],data=df,x='duration')
sns.boxplot(ax=axis[1,1],data=df,x='duration')

sns.histplot(ax=axis[2,0],data=df,x='campaign')
sns.boxplot(ax=axis[3,0],data=df,x='campaign')

sns.histplot(ax=axis[2,1],data=df,x='pdays')
sns.boxplot(ax=axis[3,1],data=df,x='pdays')

sns.histplot(ax=axis[4,0],data=df,x='previous')
sns.boxplot(ax=axis[5,0],data=df,x='previous')

sns.histplot(ax=axis[4,1],data=df,x='emp.var.rate')
sns.boxplot(ax=axis[5,1],data=df,x='emp.var.rate')

sns.histplot(ax=axis[6,0],data=df,x='cons.price.idx')
sns.boxplot(ax=axis[7,0],data=df,x='cons.price.idx')

sns.histplot(ax=axis[6,1],data=df,x='cons.conf.idx')
sns.boxplot(ax=axis[7,1],data=df,x='cons.conf.idx')

sns.histplot(ax=axis[8,0],data=df,x='euribor3m')
sns.boxplot(ax=axis[9,0],data=df,x='euribor3m')

sns.histplot(ax=axis[8,1],data=df,x='nr.employed')
sns.boxplot(ax=axis[9,1],data=df,x='nr.employed')

plt.tight_layout()
plt.show()

# %%
#Factorizando las variables categóricas

df['job_num']= pd.factorize(df['job'])[0]
df['marital_num']= pd.factorize(df['marital'])[0]
df['education_num']= pd.factorize(df['education'])[0]
df['default_num']= pd.factorize(df['default'])[0]
df['housing_num']= pd.factorize(df['housing'])[0]
df['loan_num']= pd.factorize(df['loan'])[0]
df['contact_num']= pd.factorize(df['contact'])[0]
df['month_num']= pd.factorize(df['month'])[0]
df['day_of_week_num']= pd.factorize(df['day_of_week'])[0]
df['poutcome_num']= pd.factorize(df['poutcome'])[0]
df['y_num']= pd.factorize(df['y'])[0]

# %%
#Análisis Multivariante
#Análisis numérico - numérico (¿o esto sería numérico categórico porque se factorizó?)

fig, axis = plt.subplots(10, 2, figsize = (7,25))

sns.regplot(ax = axis[0,0], data=df,x='age', y='y_num')
sns.heatmap(df[['y_num','age']].corr(),annot=True,fmt='.2f',ax=axis[1,0],cbar=False)

sns.regplot(ax = axis[0,1], data=df,x='duration', y='y_num')
sns.heatmap(df[['y_num','duration']].corr(),annot=True,fmt='.2f',ax=axis[1,1],cbar=False)

sns.regplot(ax = axis[2,0], data=df,x='campaign', y='y_num')
sns.heatmap(df[['y_num','campaign']].corr(),annot=True,fmt='.2f',ax=axis[3,0],cbar=False)

sns.regplot(ax = axis[2,1], data=df,x='pdays', y='y_num')
sns.heatmap(df[['y_num','pdays']].corr(),annot=True,fmt='.2f',ax=axis[3,1],cbar=False)

sns.regplot(ax = axis[4,0], data=df,x='previous', y='y_num')
sns.heatmap(df[['y_num','previous']].corr(),annot=True,fmt='.2f',ax=axis[5,0],cbar=False)

sns.regplot(ax = axis[4,1], data=df,x='emp.var.rate', y='y_num')
sns.heatmap(df[['y_num','emp.var.rate']].corr(),annot=True,fmt='.2f',ax=axis[5,1],cbar=False)

sns.regplot(ax = axis[6,0], data=df,x='cons.price.idx', y='y_num')
sns.heatmap(df[['y_num','cons.price.idx']].corr(),annot=True,fmt='.2f',ax=axis[7,0],cbar=False)

sns.regplot(ax = axis[6,1], data=df,x='cons.conf.idx', y='y_num')
sns.heatmap(df[['y_num','cons.conf.idx']].corr(),annot=True,fmt='.2f',ax=axis[7,1],cbar=False)

sns.regplot(ax = axis[8,0], data=df,x='euribor3m', y='y_num')
sns.heatmap(df[['y_num','euribor3m']].corr(),annot=True,fmt='.2f',ax=axis[9,0],cbar=False)

sns.regplot(ax = axis[8,1], data=df,x='nr.employed', y='y_num')
sns.heatmap(df[['y_num','nr.employed']].corr(),annot=True,fmt='.2f',ax=axis[9,1],cbar=False)

plt.tight_layout()
plt.show()

# %%
#análisis categórico - categórico

fig, axis = plt.subplots(3, 2, figsize = (10,12))

Gráfico_marital_housing = sns.countplot(data=df, x='marital',hue='housing',ax=axis[0,0])
Gráfico_marital_housing.set_ylabel('')
for p in Gráfico_marital_housing.patches:
    Gráfico_marital_housing.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_marital_loan = sns.countplot(data=df, x='marital',hue='loan',ax=axis[0,1])
Gráfico_marital_loan.set_ylabel('')
for p in Gráfico_marital_loan.patches:
    Gráfico_marital_loan.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_marital_default = sns.countplot(data=df, x='marital',hue='default',ax=axis[1,0])
Gráfico_marital_default.set_ylabel('')
for p in Gráfico_marital_default.patches:
    Gráfico_marital_default.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_marital_y = sns.countplot(data=df, x='marital',hue='y',ax=axis[1,1])
Gráfico_marital_y.set_ylabel('')
for p in Gráfico_marital_y.patches:
    Gráfico_marital_y.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_job_y = sns.countplot(data=df, x='job',hue='y',ax=axis[2,0])
Gráfico_job_y.set_ylabel('')
Gráfico_job_y.set_xticklabels(axis[2,0].get_xticklabels(), rotation=90)
for p in Gráfico_job_y.patches:
    Gráfico_job_y.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

Gráfico_education_y = sns.countplot(data=df, x='education',hue='y',ax=axis[2,1])
Gráfico_education_y.set_ylabel('')
Gráfico_education_y.set_xticklabels(axis[2,1].get_xticklabels(), rotation=90)
for p in Gráfico_education_y.patches:
    Gráfico_education_y.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_598/104237059.py:71: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Gráfico_job_y.set_xticklabels(axis[2,0].get_xticklabels(), rotation=90)
# /tmp/ipykernel_598/104237059.py:88: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   Gráfico_education_y.set_xticklabels(axis[2,1].get_xticklabels(), rotation=90)

# %%
fig, axis = plt.subplots(3, 2, figsize = (10,12))

Gráfico_poutcome_y = sns.countplot(data=df, x='poutcome',hue='y',col='marital',kind='count',ax=axis[0,0])
Gráfico_poutcome_y.set_ylabel('')
for p in Gráfico_poutcome_y.patches:
    Gráfico_poutcome_y.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2., p.get_height()),  
        ha='center',  
        va='baseline', 
        fontsize=10,  
        color='black',
        rotation=90,
        weight= 'bold',
        xytext=(0, 5), 
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 fig, axis = plt.subplots(3, 2, figsize = (10,12))
# ----> 3 Gráfico_poutcome_y = sns.countplot(data=df, x='poutcome',hue='y',col='marital',kind='count',ax=axis[0,0])
#       4 Gráfico_poutcome_y.set_ylabel('')
#       5 for p in Gráfico_poutcome_y.patches:
#
# File ~/.local/lib/python3.10/site-packages/seaborn/categorical.py:2675, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2671     p.plot_data[count_axis] /= len(p.plot_data) / denom
#    2673 aggregator = EstimateAggregator("sum", errorbar=None)
# -> 2675 p.plot_bars(
#    2676     aggregator=aggregator,
#    2677     dodge=dodge,
#    2678     width=width,
#    2679     gap=gap,
#    2680     color=color,
# ...
